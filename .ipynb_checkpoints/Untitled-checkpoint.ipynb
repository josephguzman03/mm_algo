# %%
import pandas as pd  # type: ignore
import numpy as np  # type: ignore
import data_cleaning

# %%
df = pd.read_csv('all_schools.csv')
copy = df[:10]
copy
# Out:
#    Rk              School   G   W   L   W-L%    SRS    SOS  Unnamed: 8  W.1  \
# 0   1   Abilene Christian  32  16  16  0.500  -5.47  -2.02         NaN    8
# 1   2           Air Force  32   4  28  0.125  -7.75   3.96         NaN    1
# 2   3          Akron NCAA  34  28   6  0.824   3.54  -4.52         NaN   17
# 3   4        Alabama NCAA  33  25   8  0.758  25.96  16.26         NaN   13
# 4   5         Alabama A&M  32  10  22  0.313 -20.36  -9.77         NaN    6
# 5   6  Alabama State NCAA  34  19  15  0.559  -9.23  -8.93         NaN   12
# 6   7         Albany (NY)  33  17  16  0.515  -9.45  -8.26         NaN    8
# 7   8        Alcorn State  32  11  21  0.344 -13.79  -6.69         NaN   11
# 8   9       American NCAA  34  22  12  0.647  -7.01  -6.54         NaN   13
# 9  10   Appalachian State  31  17  14  0.548  -2.47  -3.72         NaN   10
#
#    ...   FT  FTA    FT%  ORB   TRB  AST  STL  BLK  TOV   PF
# 0  ...  476  666  0.715  355  1081  421  331   94  476  670
# ...

# %%
# def cleaned(df):
#     df = df.copy() 
#     df['NCAA'] = df['School'].str.contains('NCAA').astype(int)
#     df['School'] = df['School'].str.replace('NCAA', '', regex=False)
#     df = df.drop(columns = [i for i in copy.columns if 'Unnamed' in i])
#     df = copy.rename(columns={'W.1': 'Conf. W', 'W.2': 'Home W', 'W.3': 'Away W'})
#     df = copy.rename(columns={'L.1': 'Conf. L', 'L.2': 'Home L', 'L.3': 'Away L'})
#     return df

# %%
cleaned(copy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 cleaned(copy)
#
# NameError: name 'cleaned' is not defined
